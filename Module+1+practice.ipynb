# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

fruits=pd.read_csv("fruit_data_with_colors.csv")

# %%
fruits.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
fruits
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
fruits.shape
# Out:
# (59, 7)

# %%
lookup_fruit_name=dict(zip(fruits.fruit_label.unique(),fruits.fruit_name.unique()))

# %%
lookup_fruit_name
# Out:
# {1: 'apple', 2: 'mandarin', 3: 'orange', 4: 'lemon'}

# %%
x=fruits[['mass','width','height','color_score']]
y=fruits['fruit_label']
#x
x_train, x_test, y_train, y_test=train_test_split(x,y,random_state=0)

# %%
x_train.shape
# Out:
# (44, 4)

# %%
x_test.shape
# Out:
# (15, 4)

# %%
y_train.shape
# Out:
# (44,)

# %%
y_test.shape
# Out:
# (15,)

# %%
from matplotlib import cm
cmap=cm.get_cmap("gnuplot")
scatter=pd.scatter_matrix(x_train,alpha=0.5,c=y_train,diagonal='kde',marker='o',s=40,hist_kwds={'bins':15},figsize=(12,12),cmap=cmap,grid=True)
plt.show()

# %%
from matplotlib import cm
cmap=cm.get_cmap("gnuplot")
scatter=pd.scatter_matrix(x_train,c=y_train,alpha=1,marker='o',hist_kwds={'bins':15},s=100,figsize=(10,10),diagonal='hist',cmap=cmap)
plt.show()

# %%
from matplotlib import cm
cmat=cm.get_cmap('gnuplot')
scatter=pd.scatter_matrix(x_train,c=y_train,alpha=0.5,marker='o',figsize=(10,10),hist_kwds={'bins':15},cmap=cmap)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=Axes3D(fig)
#ax=fig.add_subplot(111,projection ='3d')
ax.scatter(x_train['width'],x_train['height'],x_train['color_score'],c=y_train,marker='o',s=200,label="oranges")
ax.set_xlabel('width')
ax.set_ylabel('height')
ax.set_zlabel('color_score')
plt.legend()
plt.show()

# %%
#create classifier object
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
 knn.score(x_test,y_test)
# Out:
# 0.53333333333333333

# %%
fruit_prediction = knn.predict([[190,8.7,7.3,0.55]])
lookup_fruit_name[fruit_prediction[0]]
# Out:
# 'lemon'

# %%
fruit_prediction=knn.predict([[100,6.3,8.5,0.43]])
lookup_fruit_name[fruit_prediction[0]]
# Out:
# 'lemon'

# %%
from adspy_shared_utilities import plot_fruit_knn
plot_fruit_knn(x_train,y_train,3,'distance')
plot_fruit_knn(x_train,y_train,10,'uniform') #treat all neighbors equally
plot_fruit_knn(x_train,y_train,1,'uniform')
plot_fruit_knn(x_train,y_train,5,'uniform')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knn.score(x_test,y_test)
# Out:
# 0.53333333333333333

# %%
prediction=knn.predict([[178,7.1,7.8,0.92]])
lookup_fruit_name[prediction[0]]
# Out:
# 'apple'

# %%
prediction1=knn.predict([[104,3.2,5.6,0.50]])
lookup_fruit_name[prediction1[0]]
# Out:
# 'lemon'

# %%
from adspy_shared_utilities import plot_fruit_knn

plot_fruit_knn(x_train,y_train,3,'uniform')
